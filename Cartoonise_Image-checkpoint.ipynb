# %%
# Import Libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read Image
test_image = cv2.imread('./me.jpg')

# %%
#Image Resizing
test_image = cv2.resize(test_image, (350, 466))

# %%
plt.imshow(test_image)

# %%
# Convert from BGR to RGB
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

# %%
def display(test_image):
    plt.figure(figuresize=(10,10))

# %%
plt.imshow(test_image)

# %%
test_image
# Out:
# array([[[228, 218, 182],
#         [228, 218, 182],
#         [228, 218, 182],
#         ...,
#         [215, 210, 181],
#         [215, 210, 181],
#         [215, 210, 181]],
#
#        [[228, 218, 182],
#         [228, 218, 182],
#         [228, 218, 182],
#         ...,
#         [215, 210, 181],
#         [215, 210, 181],
#         [215, 210, 181]],
#
#        [[228, 218, 182],
#         [228, 218, 182],
#         [228, 218, 182],
#         ...,
#         [215, 210, 181],
#         [215, 210, 181],
#         [215, 210, 181]],
#
#        ...,
#
#        [[161, 167, 181],
#         [160, 166, 180],
#         [161, 164, 179],
#         ...,
#         [201, 207, 221],
#         [199, 207, 220],
#         [196, 204, 217]],
#
#        [[160, 166, 180],
#         [160, 167, 181],
#         [163, 166, 181],
#         ...,
#         [203, 209, 223],
#         [201, 209, 222],
#         [201, 209, 222]],
#
#        [[156, 162, 176],
#         [157, 163, 177],
#         [161, 164, 179],
#         ...,
#         [201, 207, 221],
#         [200, 208, 221],
#         [201, 209, 222]]], dtype=uint8)

# %%
test_image.shape
# Out:
# (466, 350, 3)

# %%
# Histogram (Graphical representation of the distribution of pixel intensities)
hist = cv2.calcHist([test_image], [2], None, [256], [0, 256])

# %%
plt.plot(hist)

# %%
# Convert to grayscale
gray_image = cv2.cvtColor(test_image, cv2.COLOR_RGB2GRAY)

# %%
def display(x,y):
    f , (ax1,ax2) = plt.subplots(1,2, figsize = (10,10))
    ax1.imshow(x)
    ax2.imshow(y)

# %%
display(test_image, gray_image)

# %%
num_down = 2
num_bilateral = 7

# %%
# downsample image using Gaussian pyramid
colour_image = test_image
for _ in range(num_down):
   colour_image = cv2.pyrDown(colour_image)

# %%
# display test_image
plt.figure(figsize=(5,5))
plt.imshow(colour_image)

# %%
# repeatedly apply small bilateral filter instead of applying one large filter
for _ in range(num_bilateral):
    colour_image = cv2.bilateralFilter(colour_image, d=9,
                                    sigmaColor=9,
                                    sigmaSpace=7)

# %%
# display test_image
plt.figure(figsize=(5,5))
plt.imshow(colour_image)

# %%
# upsample image to original size
for _ in range(num_down):
    colour_image = cv2.pyrUp(colour_image)

# %%
# display test_image
plt.figure(figsize=(5,5))
plt.imshow(colour_image)

# %%
# Preprocessing the image with Median Filter using 5 pixel value
gray_image = cv2.medianBlur(gray_image, 5)

# %%
plt.imshow(gray_image)

# %%
# Detect and enhance the edges using adaptive thresholding
edges = cv2.adaptiveThreshold(gray_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 9)

# %%
plt.imshow(edges)

# %%
# Usng Bilateral Filter to filter images while preserving edges (the bilateral filter acts more like a Gaussian blur filter)
colour_image = cv2.bilateralFilter(test_image, 9, 150, 150)

# %%
plt.imshow(colour_image)

# %%
# fuse the two effects together into a single image using cv2.bitwise_and
cartoonised_image =  cv2.bitwise_and(colour_image, colour_image, mask=edges)

# %%
plt.imshow(cartoonised_image)

# %%
display(test_image, gray_image)

# %%
display(edges, cartoonised_image)

# %%
#The cv::waitKey(n) function is used to introduce a delay of n milliseconds while rendering images to windows. 
cv2.imshow('Image', test_image)
cv2.imshow("Cartoon", cartoonised_image)
cv2.imshow("colour_image", colour_image)
cv2.imshow("edges", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
